# %%
import pandas as pd

# %% [markdown]
# #### 1. Structure the aggregated skill extraction data across key tech roles

# %%
analytics_data = [
    # Data Analyst
    {"Job_Role": "Data Analyst", "Skill": "SQL", "Category": "Database", "Demand_Count": 420, "Posting_Month": "2026-01"},
    {"Job_Role": "Data Analyst", "Skill": "Excel", "Category": "Analytics", "Demand_Count": 380, "Posting_Month": "2026-02"},
    {"Job_Role": "Data Analyst", "Skill": "Power BI", "Category": "Analytics", "Demand_Count": 350, "Posting_Month": "2026-03"},
    {"Job_Role": "Data Analyst", "Skill": "Python", "Category": "Programming", "Demand_Count": 290, "Posting_Month": "2026-03"},
    {"Job_Role": "Data Analyst", "Skill": "Tableau", "Category": "Analytics", "Demand_Count": 260, "Posting_Month": "2026-04"},
    
    # Data Scientist
    {"Job_Role": "Data Scientist", "Skill": "Python", "Category": "Programming", "Demand_Count": 510, "Posting_Month": "2026-01"},
    {"Job_Role": "Data Scientist", "Skill": "Machine Learning", "Category": "Machine Learning", "Demand_Count": 460, "Posting_Month": "2026-02"},
    {"Job_Role": "Data Scientist", "Skill": "SQL", "Category": "Database", "Demand_Count": 390, "Posting_Month": "2026-03"},
    {"Job_Role": "Data Scientist", "Skill": "Deep Learning", "Category": "Machine Learning", "Demand_Count": 280, "Posting_Month": "2026-03"},
    {"Job_Role": "Data Scientist", "Skill": "AWS", "Category": "Cloud", "Demand_Count": 230, "Posting_Month": "2026-04"},
    
    # Data Engineer
    {"Job_Role": "Data Engineer", "Skill": "SQL", "Category": "Database", "Demand_Count": 480, "Posting_Month": "2026-01"},
    {"Job_Role": "Data Engineer", "Skill": "Python", "Category": "Programming", "Demand_Count": 410, "Posting_Month": "2026-02"},
    {"Job_Role": "Data Engineer", "Skill": "AWS", "Category": "Cloud", "Demand_Count": 390, "Posting_Month": "2026-03"},
    {"Job_Role": "Data Engineer", "Skill": "Spark", "Category": "Database", "Demand_Count": 340, "Posting_Month": "2026-03"},
    {"Job_Role": "Data Engineer", "Skill": "PostgreSQL", "Category": "Database", "Demand_Count": 270, "Posting_Month": "2026-04"},

    # Software / Cloud Engineer
    {"Job_Role": "Cloud Engineer", "Skill": "AWS", "Category": "Cloud", "Demand_Count": 530, "Posting_Month": "2026-01"},
    {"Job_Role": "Cloud Engineer", "Skill": "Docker", "Category": "Cloud", "Demand_Count": 360, "Posting_Month": "2026-02"},
    {"Job_Role": "Cloud Engineer", "Skill": "Linux", "Category": "Programming", "Demand_Count": 310, "Posting_Month": "2026-03"},
    {"Job_Role": "Cloud Engineer", "Skill": "Python", "Category": "Programming", "Demand_Count": 290, "Posting_Month": "2026-04"}
]

df_dashboard = pd.DataFrame(analytics_data)

# %% [markdown]
# #### 2. Inspecting the dataset

# %%
print("Dashboard Feed Preview:")
display(df_dashboard.head())
# Out:
# Dashboard Feed Preview:
#        Job_Role     Skill     Category  Demand_Count Posting_Month
# 0  Data Analyst       SQL     Database           420       2026-01
# 1  Data Analyst     Excel    Analytics           380       2026-02
# 2  Data Analyst  Power BI    Analytics           350       2026-03
# 3  Data Analyst    Python  Programming           290       2026-03
# 4  Data Analyst   Tableau    Analytics           260       2026-04

# %% [markdown]
# #### 3. Exporting for Power BI

# %%
df_dashboard.to_csv("dashboard_data.csv", index=False)
print("\nExported: 'dashboard_data.csv' is ready for Power BI import.")
# Out:
# Exported: 'dashboard_data.csv' is ready for Power BI import.
